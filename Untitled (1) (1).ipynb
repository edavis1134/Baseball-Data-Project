# %%
import requests # apache http library
import xml.etree.ElementTree as ET # XML parsing 
import os # file and system level 

import pandas as pd  # dataframes, structures, analysis 
import numpy as np   # used by pandas

#enable inline notebook plotting 
# %matplotlib inline  

from termcolor import colored  # colored output using print
print("Hello world.")
print(colored("Hello back.", "red"))
# Out:
# Hello world.
# Hello back.

# %% [markdown]
# ## Pull Players into Dictionary

# %%
# url of players feed 
url = 'https://gd2.mlb.com/components/game/mlb/year_2014/month_06/day_18/gid_2014_06_18_colmlb_lanmlb_1/players.xml'
#url = "https://gd2.mlb.com/components/game/mlb/year_2018/month_08/day_12/gid_2018_08_12_lanmlb_colmlb_1/players.xml"
resp = requests.get(url) 
print(colored(resp,"blue"))
xmlfile = "myplayers.xml"
with open(xmlfile, 'wb') as f: 
    f.write(resp.content)
statinfo = os.stat(xmlfile)  
print(colored(xmlfile + ": " + str(round(statinfo.st_size/1024)) + " KB\n", "blue"))

# Pull players into tree structure <game><team><player><player></team><team><player><player></team></game>
tree = ET.parse(xmlfile)
game = tree.getroot()
teams = game.findall("./team")
playerDict = {}

### Verify Player Dictionary
for team in teams:
    print(team.attrib.get("name"))
    players = team.findall("./player")
    for player in players:
        print("   ", player.attrib.get("id"), player.attrib.get("first"), player.attrib.get("last"))
        playerDict[ player.attrib.get("id") ] = player.attrib.get("first") + " " + player.attrib.get("last")
# Out:
# <Response [200]>
# myplayers.xml: 16 KB
#
# Colorado Rockies
#     518934 DJ LeMahieu
#     572816 Corey Dickerson
#     279571 Matt Belisle
#     453211 Drew Stubbs
#     554431 Tyler Matzek
#     408047 Justin Morneau
#     462985 Franklin Morales
#     592621 Kyle Parker
#     571521 Rex Brothers
#     548357 Christian Bergman
#     493603 Adam Ottavino
#     501647 Wilin Rosario
#     434665 Nick Masset
#     453568 Charlie Blackmon
#     488681 Brandon Barnes
#     502374 Michael McKenry
#     115629 LaTroy Hawkins
#     518586 Charlie Culberson
#     592454 Tommy Kahnle
#     592710 Josh Rutledge
#     453064 Troy Tulowitzki
#     407822 Jorge De La Rosa
#     468504 Jhoulys Chacin
#     572253 Ryan Wheeler
#     455119 Chris Martin
# Los Angeles Dodgers
#     508892 Carlos Triunfel
#     475100 Scott Van Slyke
#     453198 Chris Perez
#     454560 A.J. Ellis
#     461314 Matt Kemp
#     425844 Zack Greinke
#     444843 Andre Ethier
#     434181 Brandon League
#     460077 Drew Butera
#     124604 Jamey Wright
#     434442 J.P. Howell
#     445276 Kenley Jansen
#     430904 Paul Maholm
#     547943 Hyun Jin Ryu
#     457449 Jamie Romak
#     624577 Yasiel Puig
#     543829 Dee Strange-Gordon
#     429717 Dan Haren
#     408236 Adrian Gonzalez
#     477132 Clayton Kershaw
#     277417 Josh Beckett
#     434670 Hanley Ramirez
#     500743 Miguel Rojas
#     451216 Brian Wilson
#     457759 Justin Turner

# %%
playerDict["624577"]
# Out:
# 'Yasiel Puig'

# %% [markdown]
# ## Clayton Kershaw No-Hitter - June 18, 2014, Dodgers vs. Rockies, 8-0
#
# Jun 18, 2014 - Kershaw no-hit the Rockies while striking out 15 and not walking a single batter. There have been 283 no-hitters in baseball history, but Kershaw is the only one to have at least 15 strikeouts and no walks. Only one other pitcher has even thrown a no-hitter with at least 15 strikeouts. ... He needed only 107 pitches.
#
# #### Get Innings_All Data

# %%
url = 'https://www.powerchalk.com/downloads/pitchfx/inning_all.xml'
resp = requests.get(url) 
print(colored(resp,"blue"))
xmlfile = "mygame.xml"
with open(xmlfile, 'wb') as f: 
    f.write(resp.content)
statinfo = os.stat(xmlfile)  
print(colored(xmlfile + ": " + str(round(statinfo.st_size/1024)) + " KB\n", "blue"))

# Pull XML into tree structure
tree = ET.parse(xmlfile)
root = tree.getroot()
print("Tree.root.tag = " + root.tag)

# Unpack the game to find innings
for child in root:
    print (child.tag, child.attrib.get("num"))
    for frame in child:
        print ("   ", frame.tag, frame.attrib) # type(frame))
# Out:
# <Response [200]>
# mygame.xml: 196 KB
#
# Tree.root.tag = game
# inning 1
#     top {}
#     bottom {}
# inning 2
#     top {}
#     bottom {}
# inning 3
#     top {}
#     bottom {}
# inning 4
#     top {}
#     bottom {}
# inning 5
#     top {}
#     bottom {}
# inning 6
#     top {}
#     bottom {}
# inning 7
#     top {}
#     bottom {}
# inning 8
#     top {}
#     bottom {}
# inning 9
#     top {}

# %%
frames = ["top", "bottom"]
pitchDictionary = { "FA":"fastball", "FF":"4-seam fb", "FT": "2-seam fb", "FC": "fb-cutter", "":"unknown", None: "none",
                    "FS":"fb-splitter", "SL":"slider", "CH":"changeup","CU":"curveball","KC":"knuckle-curve",
                    "KN":"knuckleball","EP":"eephus", "UN":"unidentified", "PO":"pitchout", "SI":"sinker", "SF":"split-finger"
                    }
totalPitchCount = 0

innings = root.findall("./inning")
for inning in innings:
    for i in range(len(frames)):
        color = "green" if i == 0 else "yellow" #show top of inning in green; bottom in yellow
        print(colored("\nInning " + inning.attrib.get("num") + " (" + frames[i] + ")", color, attrs=['reverse']))
        fr = inning.find(frames[i])
        if fr is not None:
            for ab in fr.iter('atbat'):
                #battername = ab.get('batter')
                battername = playerDict[ab.get('batter')]
                abPitchCount = 0
                print (colored("   " + battername, color, attrs=['bold']))
                
                pitches = ab.findall("pitch")
                #print(pitches)
                for p in pitches:
                    abPitchCount = abPitchCount + 1
                    totalPitchCount = totalPitchCount + 1
                    verbosePitch = pitchDictionary[p.get("pitch_type")]
                    print(colored("      pitch " + str(abPitchCount) + ": " + verbosePitch, color))
                print("      " + colored( ab.attrib.get("event"), color, attrs=['underline']))
print("Total pitches: " + str(totalPitchCount))
# Out:
# Inning 1 (top)
#    Corey Dickerson
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: slider
#       pitch 5: 4-seam fb
#       pitch 6: slider
#       Strikeout
#    Brandon Barnes
#       pitch 1: 4-seam fb
#       Flyout
#    Troy Tulowitzki
#       pitch 1: 4-seam fb
#       pitch 2: slider
#       pitch 3: curveball
#       pitch 4: slider
#       pitch 5: 4-seam fb
#       Groundout
#
# Inning 1 (bottom)
#    Dee Strange-Gordon
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: 4-seam fb
#       pitch 5: 4-seam fb
#       pitch 6: 4-seam fb
#       pitch 7: 4-seam fb
#       pitch 8: 4-seam fb
#       Walk
#    Hanley Ramirez
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: 4-seam fb
#       pitch 4: 4-seam fb
#       pitch 5: 4-seam fb
#       pitch 6: fb-splitter
#       Walk
#    Yasiel Puig
#       pitch 1: 4-seam fb
#       pitch 2: fb-splitter
#       pitch 3: fb-cutter
#       pitch 4: 4-seam fb
#       Sac Fly
#    Adrian Gonzalez
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: fb-splitter
#       Groundout
#    Matt Kemp
#       pitch 1: 4-seam fb
#       pitch 2: fb-splitter
#       pitch 3: 4-seam fb
#       pitch 4: fb-cutter
#       pitch 5: 4-seam fb
#       pitch 6: fb-splitter
#       Single
#    Scott Van Slyke
#       pitch 1: 4-seam fb
#       Lineout
#
# Inning 2 (top)
#    Wilin Rosario
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: curveball
#       Strikeout
#    Drew Stubbs
#       pitch 1: 4-seam fb
#       pitch 2: slider
#       pitch 3: 4-seam fb
#       pitch 4: curveball
#       pitch 5: slider
#       Strikeout
#    Josh Rutledge
#       pitch 1: 4-seam fb
#       pitch 2: curveball
#       pitch 3: changeup
#       pitch 4: slider
#       pitch 5: slider
#       pitch 6: curveball
#       pitch 7: 4-seam fb
#       pitch 8: slider
#       Groundout
#
# Inning 2 (bottom)
#    A.J. Ellis
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       Flyout
#    Miguel Rojas
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: fb-splitter
#       Groundout
#    Clayton Kershaw
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       Groundout
#
# Inning 3 (top)
#    Kyle Parker
#       pitch 1: 4-seam fb
#       pitch 2: slider
#       pitch 3: slider
#       pitch 4: 4-seam fb
#       pitch 5: curveball
#       pitch 6: slider
#       pitch 7: 4-seam fb
#       Strikeout
#    DJ LeMahieu
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: slider
#       pitch 5: slider
#       Strikeout
#    Jorge De La Rosa
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: 4-seam fb
#       pitch 5: 4-seam fb
#       Lineout
#
# Inning 3 (bottom)
#    Dee Strange-Gordon
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: fb-cutter
#       pitch 4: fb-cutter
#       pitch 5: fb-splitter
#       pitch 6: 4-seam fb
#       Groundout
#    Hanley Ramirez
#       pitch 1: fb-cutter
#       pitch 2: 4-seam fb
#       pitch 3: fb-splitter
#       pitch 4: 4-seam fb
#       Groundout
#    Yasiel Puig
#       pitch 1: fb-cutter
#       pitch 2: fb-cutter
#       pitch 3: fb-splitter
#       pitch 4: fb-splitter
#       pitch 5: 4-seam fb
#       pitch 6: fb-cutter
#       pitch 7: fb-cutter
#       pitch 8: 4-seam fb
#       pitch 9: fb-splitter
#       Walk
#    Adrian Gonzalez
#       pitch 1: 4-seam fb
#       Double
#    Matt Kemp
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: 4-seam fb
#       Double
#    Scott Van Slyke
#       pitch 1: 4-seam fb
#       pitch 2: fb-splitter
#       pitch 3: fb-splitter
#       pitch 4: fb-splitter
#       pitch 5: 4-seam fb
#       pitch 6: fb-splitter
#       pitch 7: fb-splitter
#       Walk
#    A.J. Ellis
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: 4-seam fb
#       pitch 4: fb-cutter
#       pitch 5: 4-seam fb
#       pitch 6: fb-splitter
#       pitch 7: 4-seam fb
#       Walk
#    Miguel Rojas
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       Double
#    Clayton Kershaw
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       Groundout
#
# Inning 4 (top)
#    Corey Dickerson
#       pitch 1: 4-seam fb
#       pitch 2: curveball
#       pitch 3: slider
#       Groundout
#    Brandon Barnes
#       pitch 1: 4-seam fb
#       pitch 2: slider
#       pitch 3: slider
#       Strikeout
#    Troy Tulowitzki
#       pitch 1: 4-seam fb
#       pitch 2: curveball
#       Flyout
#
# Inning 4 (bottom)
#    Dee Strange-Gordon
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: fb-cutter
#       Strikeout
#    Hanley Ramirez
#       pitch 1: curveball
#       pitch 2: fb-cutter
#       pitch 3: 4-seam fb
#       pitch 4: fb-cutter
#       pitch 5: 4-seam fb
#       Single
#    Yasiel Puig
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       Double
#    Adrian Gonzalez
#       pitch 1: 4-seam fb
#       pitch 2: curveball
#       pitch 3: 4-seam fb
#       pitch 4: 4-seam fb
#       Single
#    Matt Kemp
#       pitch 1: 4-seam fb
#       pitch 2: curveball
#       pitch 3: curveball
#       pitch 4: slider
#       Grounded Into DP
#
# Inning 5 (top)
#    Wilin Rosario
#       pitch 1: slider
#       pitch 2: 4-seam fb
#       pitch 3: slider
#       pitch 4: curveball
#       pitch 5: slider
#       Strikeout
#    Drew Stubbs
#       pitch 1: 4-seam fb
#       Groundout
#    Josh Rutledge
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: curveball
#       pitch 4: slider
#       pitch 5: 4-seam fb
#       Groundout
#
# Inning 5 (bottom)
#    Scott Van Slyke
#       pitch 1: curveball
#       pitch 2: 4-seam fb
#       Single
#    A.J. Ellis
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: curveball
#       Forceout
#    Miguel Rojas
#       pitch 1: 4-seam fb
#       pitch 2: slider
#       pitch 3: 4-seam fb
#       pitch 4: slider
#       Grounded Into DP
#
# Inning 6 (top)
#    Kyle Parker
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: curveball
#       Strikeout
#    DJ LeMahieu
#       pitch 1: slider
#       pitch 2: slider
#       pitch 3: 4-seam fb
#       pitch 4: 4-seam fb
#       pitch 5: curveball
#       Strikeout
#    Ryan Wheeler
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: curveball
#       pitch 5: slider
#       Strikeout
#
# Inning 6 (bottom)
#    Clayton Kershaw
#       pitch 1: fb-cutter
#       pitch 2: 4-seam fb
#       pitch 3: sinker
#       pitch 4: 4-seam fb
#       pitch 5: 4-seam fb
#       pitch 6: 4-seam fb
#       pitch 7: curveball
#       Flyout
#    Dee Strange-Gordon
#       pitch 1: 4-seam fb
#       pitch 2: fb-cutter
#       pitch 3: fb-cutter
#       pitch 4: 4-seam fb
#       pitch 5: 4-seam fb
#       pitch 6: 4-seam fb
#       pitch 7: 4-seam fb
#       Walk
#    Hanley Ramirez
#       pitch 1: fb-cutter
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       Flyout
#    Yasiel Puig
#       pitch 1: 4-seam fb
#       Groundout
#
# Inning 7 (top)
#    Corey Dickerson
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: slider
#       pitch 4: slider
#       Field Error
#    Brandon Barnes
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: curveball
#       pitch 5: slider
#       Strikeout
#    Troy Tulowitzki
#       pitch 1: slider
#       Groundout
#    Wilin Rosario
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: slider
#       pitch 5: curveball
#       Strikeout
#
# Inning 7 (bottom)
#    Adrian Gonzalez
#       pitch 1: 4-seam fb
#       pitch 2: 2-seam fb
#       pitch 3: changeup
#       pitch 4: 2-seam fb
#       pitch 5: slider
#       pitch 6: 2-seam fb
#       Strikeout
#    Matt Kemp
#       pitch 1: slider
#       pitch 2: slider
#       Double
#    Scott Van Slyke
#       pitch 1: slider
#       Flyout
#    A.J. Ellis
#       pitch 1: 2-seam fb
#       pitch 2: slider
#       pitch 3: slider
#       pitch 4: 2-seam fb
#       pitch 5: slider
#       Lineout
#
# Inning 8 (top)
#    Drew Stubbs
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: curveball
#       Strikeout
#    Josh Rutledge
#       pitch 1: 4-seam fb
#       pitch 2: slider
#       pitch 3: slider
#       pitch 4: curveball
#       Strikeout
#    Kyle Parker
#       pitch 1: 4-seam fb
#       Groundout
#
# Inning 8 (bottom)
#    Miguel Rojas
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       pitch 4: 4-seam fb
#       pitch 5: 4-seam fb
#       Strikeout
#    Clayton Kershaw
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: 4-seam fb
#       Groundout
#    Dee Strange-Gordon
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: slider
#       pitch 4: slider
#       pitch 5: 4-seam fb
#       pitch 6: slider
#       pitch 7: 4-seam fb
#       Lineout
#
# Inning 9 (top)
#    DJ LeMahieu
#       pitch 1: 4-seam fb
#       Groundout
#    Charlie Culberson
#       pitch 1: 4-seam fb
#       Flyout
#    Corey Dickerson
#       pitch 1: 4-seam fb
#       pitch 2: 4-seam fb
#       pitch 3: curveball
#       pitch 4: slider
#       Strikeout
#
# Inning 9 (bottom)
# Total pitches: 257

# %% [markdown]
# ## Load Inning Detail in to Dataframe
#
# #### Gameday Pitch Fields Definitions:
# https://fastballs.wordpress.com/2007/08/02/glossary-of-the-gameday-pitch-fields/

# %%
frames = ["top", "bottom"]
pitchDF = pd.DataFrame(columns = ['pitchIdx', 'inning', 'frame', 'ab', 'abIdx', 'batter', 'stand', 'speed', 
                                       'pitchtype', 'px', 'pz', 'szTop', 'szBottom', 'des'], dtype=object)

totalPitchCount = 0
topPitchCount = 0 # pitches thrown by home team
bottomPitchCount = 0 # pitches thrown by visiting team

for inning in innings:
    for i in range(len(frames)):
        fr = inning.find(frames[i])
        if fr is not None:
            for ab in fr.iter('atbat'):
                #print(ab)
                battername = playerDict[ab.get('batter')]
                standside = ab.get('stand')
                abIdx = ab.get('num')
                abPitchCount = 0
                pitches = ab.findall("pitch")
                for pitch in pitches:
                    if pitch.attrib.get("start_speed") is None:
                        speed == 0
                    else:
                        speed = float(pitch.attrib.get("start_speed"))
                    pxFloat = 0.0 if pitch.attrib.get("px") == None else float('{0:.2f}'.format(float(pitch.attrib.get("px"))))
                    pzFloat = 0.0 if pitch.attrib.get("pz") == None else float('{0:.2f}'.format(float(pitch.attrib.get("pz"))))
                    szTop = 0.0 if pitch.attrib.get("sz_top") == None else float('{0:.2f}'.format(float(pitch.attrib.get("sz_top"))))
                    szBot = 0.0 if pitch.attrib.get("sz_bot") == None else float('{0:.2f}'.format(float(pitch.attrib.get("sz_bot"))))
                    print("pitch " + str(totalPitchCount) + " speed:" + str(pitch.attrib.get("start_speed")) + " frame:" + frames[i])
                    abPitchCount = abPitchCount + 1
                    totalPitchCount = totalPitchCount + 1
                    if frames[i]=='top':
                        topPitchCount = topPitchCount + 1
                    else:
                        bottomPitchCount = bottomPitchCount + 1
                    inn = inning.attrib.get("num")
                    verbosePitch = pitchDictionary[pitch.get("pitch_type")]
                    desPitch = pitch.get("des")
                    
                    #add row to dataframe
                    pitchDF.loc[totalPitchCount] = [float(totalPitchCount), inn, frames[i], abIdx, abPitchCount, battername, standside, speed,
                                               verbosePitch, pxFloat, pzFloat, szTop, szBot, desPitch]

print( str(totalPitchCount) + " pitches cataloged. Top: " + str(topPitchCount) + ". Bottom: " + str(bottomPitchCount) + ".")
# Out:
# pitch 0 speed:93.3 frame:top
# pitch 1 speed:93.3 frame:top
# pitch 2 speed:94.6 frame:top
# pitch 3 speed:90.5 frame:top
# pitch 4 speed:93.8 frame:top
# pitch 5 speed:85.0 frame:top
# pitch 6 speed:93.4 frame:top
# pitch 7 speed:94.4 frame:top
# pitch 8 speed:88.0 frame:top
# pitch 9 speed:72.4 frame:top
# pitch 10 speed:87.2 frame:top
# pitch 11 speed:93.8 frame:top
# pitch 12 speed:90.1 frame:bottom
# pitch 13 speed:90.8 frame:bottom
# pitch 14 speed:90.5 frame:bottom
# pitch 15 speed:91.8 frame:bottom
# pitch 16 speed:91.2 frame:bottom
# pitch 17 speed:92.4 frame:bottom
# pitch 18 speed:92.6 frame:bottom
# pitch 19 speed:92.9 frame:bottom
# pitch 20 speed:91.7 frame:bottom
# pitch 21 speed:87.4 frame:bottom
# pitch 22 speed:92.3 frame:bottom
# pitch 23 speed:92.4 frame:bottom
# pitch 24 speed:92.5 frame:bottom
# pitch 25 speed:84.5 frame:bottom
# pitch 26 speed:91.4 frame:bottom
# pitch 27 speed:83.3 frame:bottom
# pitch 28 speed:88.8 frame:bottom
# pitch 29 speed:93.7 frame:bottom
# pitch 30 speed:93.3 frame:bottom
# pitch 31 speed:93.2 frame:bottom
# pitch 32 speed:84.5 frame:bottom
# pitch 33 speed:93.4 frame:bottom
# pitch 34 speed:84.3 frame:bottom
# pitch 35 speed:92.4 frame:bottom
# pitch 36 speed:88.7 frame:bottom
# pitch 37 speed:92.8 frame:bottom
# pitch 38 speed:85.3 frame:bottom
# pitch 39 speed:93.5 frame:bottom
# pitch 40 speed:92.0 frame:top
# pitch 41 speed:92.1 frame:top
# pitch 42 speed:92.2 frame:top
# pitch 43 speed:72.6 frame:top
# pitch 44 speed:92.5 frame:top
# pitch 45 speed:84.6 frame:top
# pitch 46 speed:93.1 frame:top
# pitch 47 speed:74.5 frame:top
# pitch 48 speed:87.4 frame:top
# pitch 49 speed:92.6 frame:top
# pitch 50 speed:76.1 frame:top
# pitch 51 speed:87.6 frame:top
# pitch 52 speed:86.4 frame:top
# pitch 53 speed:86.7 frame:top
# pitch 54 speed:74.1 frame:top
# pitch 55 speed:93.1 frame:top
# pitch 56 speed:88.2 frame:top
# pitch 57 speed:91.1 frame:bottom
# pitch 58 speed:86.8 frame:bottom
# pitch 59 speed:91.5 frame:bottom
# pitch 60 speed:85.3 frame:bottom
# pitch 61 speed:82.4 frame:bottom
# pitch 62 speed:92.2 frame:bottom
# pitch 63 speed:86.2 frame:bottom
# pitch 64 speed:93.1 frame:top
# pitch 65 speed:85.8 frame:top
# pitch 66 speed:85.7 frame:top
# pitch 67 speed:94.9 frame:top
# pitch 68 speed:74.5 frame:top
# pitch 69 speed:87.3 frame:top
# pitch 70 speed:94.0 frame:top
# pitch 71 speed:95.0 frame:top
# pitch 72 speed:94.3 frame:top
# pitch 73 speed:94.1 frame:top
# pitch 74 speed:89.1 frame:top
# pitch 75 speed:86.8 frame:top
# pitch 76 speed:94.4 frame:top
# pitch 77 speed:93.3 frame:top
# pitch 78 speed:93.7 frame:top
# pitch 79 speed:93.5 frame:top
# pitch 80 speed:94.4 frame:top
# pitch 81 speed:90.3 frame:bottom
# pitch 82 speed:84.0 frame:bottom
# pitch 83 speed:85.6 frame:bottom
# pitch 84 speed:86.6 frame:bottom
# pitch 85 speed:82.7 frame:bottom
# pitch 86 speed:92.9 frame:bottom
# pitch 87 speed:86.5 frame:bottom
# pitch 88 speed:91.9 frame:bottom
# pitch 89 speed:82.3 frame:bottom
# pitch 90 speed:92.7 frame:bottom
# pitch 91 speed:87.4 frame:bottom
# pitch 92 speed:86.3 frame:bottom
# pitch 93 speed:83.4 frame:bottom
# pitch 94 speed:83.3 frame:bottom
# pitch 95 speed:92.9 frame:bottom
# pitch 96 speed:86.6 frame:bottom
# pitch 97 speed:87.1 frame:bottom
# pitch 98 speed:92.1 frame:bottom
# pitch 99 speed:85.0 frame:bottom
# pitch 100 speed:91.7 frame:bottom
# pitch 101 speed:93.5 frame:bottom
# pitch 102 speed:89.1 frame:bottom
# pitch 103 speed:92.5 frame:bottom
# pitch 104 speed:91.8 frame:bottom
# pitch 105 speed:83.8 frame:bottom
# pitch 106 speed:81.7 frame:bottom
# pitch 107 speed:83.1 frame:bottom
# pitch 108 speed:92.7 frame:bottom
# pitch 109 speed:83.8 frame:bottom
# pitch 110 speed:83.3 frame:bottom
# pitch 111 speed:93.5 frame:bottom
# pitch 112 speed:89.6 frame:bottom
# pitch 113 speed:92.3 frame:bottom
# pitch 114 speed:88.2 frame:bottom
# pitch 115 speed:92.2 frame:bottom
# pitch 116 speed:84.3 frame:bottom
# pitch 117 speed:92.8 frame:bottom
# pitch 118 speed:92.7 frame:bottom
# pitch 119 speed:92.7 frame:bottom
# pitch 120 speed:92.9 frame:bottom
# pitch 121 speed:92.0 frame:bottom
# pitch 122 speed:91.7 frame:top
# pitch 123 speed:72.8 frame:top
# pitch 124 speed:86.0 frame:top
# pitch 125 speed:92.5 frame:top
# pitch 126 speed:84.9 frame:top
# pitch 127 speed:86.8 frame:top
# pitch 128 speed:93.6 frame:top
# pitch 129 speed:74.1 frame:top
# pitch 130 speed:90.4 frame:bottom
# pitch 131 speed:84.4 frame:bottom
# pitch 132 speed:85.6 frame:bottom
# pitch 133 speed:73.6 frame:bottom
# pitch 134 speed:85.3 frame:bottom
# pitch 135 speed:90.7 frame:bottom
# pitch 136 speed:86.3 frame:bottom
# pitch 137 speed:91.5 frame:bottom
# pitch 138 speed:90.8 frame:bottom
# pitch 139 speed:87.1 frame:bottom
# pitch 140 speed:91.1 frame:bottom
# pitch 141 speed:72.1 frame:bottom
# pitch 142 speed:92.0 frame:bottom
# pitch 143 speed:92.5 frame:bottom
# pitch 144 speed:91.5 frame:bottom
# pitch 145 speed:74.5 frame:bottom
# pitch 146 speed:75.0 frame:bottom
# pitch 147 speed:85.7 frame:bottom
# pitch 148 speed:83.4 frame:top
# pitch 149 speed:91.8 frame:top
# pitch 150 speed:88.1 frame:top
# pitch 151 speed:73.0 frame:top
# pitch 152 speed:86.6 frame:top
# pitch 153 speed:92.7 frame:top
# pitch 154 speed:92.5 frame:top
# pitch 155 speed:92.5 frame:top
# pitch 156 speed:73.2 frame:top
# pitch 157 speed:87.3 frame:top
# pitch 158 speed:93.0 frame:top
# pitch 159 speed:71.8 frame:bottom
# pitch 160 speed:89.7 frame:bottom
# pitch 161 speed:92.4 frame:bottom
# pitch 162 speed:91.9 frame:bottom
# pitch 163 speed:75.6 frame:bottom
# pitch 164 speed:91.3 frame:bottom
# pitch 165 speed:87.5 frame:bottom
# pitch 166 speed:92.6 frame:bottom
# pitch 167 speed:88.7 frame:bottom
# pitch 168 speed:92.1 frame:top
# pitch 169 speed:91.8 frame:top
# pitch 170 speed:74.6 frame:top
# pitch 171 speed:85.0 frame:top
# pitch 172 speed:86.2 frame:top
# pitch 173 speed:94.9 frame:top
# pitch 174 speed:94.2 frame:top
# pitch 175 speed:75.3 frame:top
# pitch 176 speed:93.3 frame:top
# pitch 177 speed:92.6 frame:top
# pitch 178 speed:92.8 frame:top
# pitch 179 speed:73.3 frame:top
# pitch 180 speed:88.1 frame:top
# pitch 181 speed:91.2 frame:bottom
# pitch 182 speed:95.9 frame:bottom
# pitch 183 speed:95.8 frame:bottom
# pitch 184 speed:95.3 frame:bottom
# pitch 185 speed:96.0 frame:bottom
# pitch 186 speed:95.4 frame:bottom
# pitch 187 speed:82.6 frame:bottom
# pitch 188 speed:95.8 frame:bottom
# pitch 189 speed:89.3 frame:bottom
# pitch 190 speed:89.8 frame:bottom
# pitch 191 speed:96.3 frame:bottom
# pitch 192 speed:95.3 frame:bottom
# pitch 193 speed:95.0 frame:bottom
# pitch 194 speed:95.3 frame:bottom
# pitch 195 speed:90.7 frame:bottom
# pitch 196 speed:94.8 frame:bottom
# pitch 197 speed:94.8 frame:bottom
# pitch 198 speed:96.3 frame:bottom
# pitch 199 speed:92.4 frame:top
# pitch 200 speed:92.8 frame:top
# pitch 201 speed:86.0 frame:top
# pitch 202 speed:85.8 frame:top
# pitch 203 speed:92.5 frame:top
# pitch 204 speed:92.5 frame:top
# pitch 205 speed:92.3 frame:top
# pitch 206 speed:73.1 frame:top
# pitch 207 speed:86.0 frame:top
# pitch 208 speed:86.5 frame:top
# pitch 209 speed:93.1 frame:top
# pitch 210 speed:92.4 frame:top
# pitch 211 speed:93.2 frame:top
# pitch 212 speed:87.0 frame:top
# pitch 213 speed:74.4 frame:top
# pitch 214 speed:92.8 frame:bottom
# pitch 215 speed:93.6 frame:bottom
# pitch 216 speed:86.4 frame:bottom
# pitch 217 speed:92.3 frame:bottom
# pitch 218 speed:81.9 frame:bottom
# pitch 219 speed:93.5 frame:bottom
# pitch 220 speed:82.8 frame:bottom
# pitch 221 speed:82.2 frame:bottom
# pitch 222 speed:81.8 frame:bottom
# pitch 223 speed:94.0 frame:bottom
# pitch 224 speed:82.6 frame:bottom
# pitch 225 speed:82.2 frame:bottom
# pitch 226 speed:92.7 frame:bottom
# pitch 227 speed:83.8 frame:bottom
# pitch 228 speed:91.1 frame:top
# pitch 229 speed:91.6 frame:top
# pitch 230 speed:73.2 frame:top
# pitch 231 speed:92.4 frame:top
# pitch 232 speed:86.2 frame:top
# pitch 233 speed:85.2 frame:top
# pitch 234 speed:74.7 frame:top
# pitch 235 speed:93.6 frame:top
# pitch 236 speed:90.6 frame:bottom
# pitch 237 speed:91.6 frame:bottom
# pitch 238 speed:91.6 frame:bottom
# pitch 239 speed:92.2 frame:bottom
# pitch 240 speed:94.0 frame:bottom
# pitch 241 speed:90.8 frame:bottom
# pitch 242 speed:90.5 frame:bottom
# pitch 243 speed:91.4 frame:bottom
# pitch 244 speed:93.1 frame:bottom
# pitch 245 speed:93.7 frame:bottom
# pitch 246 speed:84.2 frame:bottom
# pitch 247 speed:88.4 frame:bottom
# pitch 248 speed:93.5 frame:bottom
# pitch 249 speed:86.1 frame:bottom
# pitch 250 speed:91.9 frame:bottom
# pitch 251 speed:93.0 frame:top
# pitch 252 speed:93.7 frame:top
# pitch 253 speed:94.3 frame:top
# pitch 254 speed:94.5 frame:top
# pitch 255 speed:73.6 frame:top
# pitch 256 speed:86.5 frame:top
# 257 pitches cataloged. Top: 107. Bottom: 150.

# %%
pitchDF.head(25)
# Out:
#     pitchIdx inning   frame ab abIdx              batter stand  speed  \
# 1        1.0      1     top  1     1     Corey Dickerson     L   93.3
# 2        2.0      1     top  1     2     Corey Dickerson     L   93.3
# 3        3.0      1     top  1     3     Corey Dickerson     L   94.6
# 4        4.0      1     top  1     4     Corey Dickerson     L   90.5
# 5        5.0      1     top  1     5     Corey Dickerson     L   93.8
# 6        6.0      1     top  1     6     Corey Dickerson     L   85.0
# 7        7.0      1     top  2     1      Brandon Barnes     R   93.4
# 8        8.0      1     top  3     1     Troy Tulowitzki     R   94.4
# 9        9.0      1     top  3     2     Troy Tulowitzki     R   88.0
# 10      10.0      1     top  3     3     Troy Tulowitzki     R   72.4
# 11      11.0      1     top  3     4     Troy Tulowitzki     R   87.2
# 12      12.0      1     top  3     5     Troy Tulowitzki     R   93.8
# 13      13.0      1  bottom  4     1  Dee Strange-Gordon     L   90.1
# 14      14.0      1  bottom  4     2  Dee Strange-Gordon     L   90.8
# 15      15.0      1  bottom  4     3  Dee Strange-Gordon     L   90.5
# 16      16.0      1  bottom  4     4  Dee Strange-Gordon     L   91.8
# 17      17.0      1  bottom  4     5  Dee Strange-Gordon     L   91.2
# 18      18.0      1  bottom  4     6  Dee Strange-Gordon     L   92.4
# 19      19.0      1  bottom  4     7  Dee Strange-Gordon     L   92.6
# 20      20.0      1  bottom  4     8  Dee Strange-Gordon     L   92.9
# 21      21.0      1  bottom  5     1      Hanley Ramirez     R   91.7
# 22      22.0      1  bottom  5     2      Hanley Ramirez     R   87.4
# 23      23.0      1  bottom  5     3      Hanley Ramirez     R   92.3
# 24      24.0      1  bottom  5     4      Hanley Ramirez     R   92.4
# 25      25.0      1  bottom  5     5      Hanley Ramirez     R   92.5
#
#     pitchtype    px    pz  szTop  szBottom              des
# 1   4-seam fb -0.52  1.86   3.40      1.51             Foul
# 2   4-seam fb -0.37  2.75   3.40      1.51  Swinging Strike
# 3   4-seam fb -1.67  1.33   3.66      1.71             Ball
# 4      slider -2.00  0.36   3.53      1.58             Ball
# 5   4-seam fb -0.26  3.47   3.40      1.51             Foul
# 6      slider -0.28  3.33   3.48      1.61    Called Strike
# 7   4-seam fb  0.05  2.59   3.53      1.60  In play, out(s)
# 8   4-seam fb  0.03  1.09   3.64      1.59             Ball
# 9      slider -1.39  0.61   3.58      1.71  Swinging Strike
# 10  curveball  0.59  4.08   3.38      1.75             Ball
# 11     slider -0.60  1.75   3.58      1.71             Foul
# 12  4-seam fb  0.96  3.39   3.58      1.71  In play, out(s)
# 13  4-seam fb -0.75  0.71   3.29      1.48             Ball
# 14  4-seam fb -0.77  1.23   3.28      1.48             Ball
# 15  4-seam fb  0.66  2.45   3.28      1.51    Called Strike
# 16  4-seam fb -2.36  1.59   3.35      1.41             Ball
# 17  4-seam fb  0.51  2.84   3.22      1.41    Called Strike
# 18  4-seam fb -0.27  2.61   3.36      1.48             Foul
# 19  4-seam fb  0.20  2.81   3.36      1.48             Foul
# 20  4-seam fb -0.98  0.36   3.39      1.52     Ball In Dirt
# 21  4-seam fb  0.09  2.07   3.51      1.63             Foul
# 22  fb-cutter -0.83  2.02   3.51      1.63             Foul
# 23  4-seam fb -1.65  1.03   3.55      1.65             Ball
# 24  4-seam fb -0.26  0.87   3.61      1.84             Ball
# 25  4-seam fb  1.09  1.23   3.48      1.74             Ball

# %%
pitchDF.dtypes
pitchDF.columns
# Out:
# Index(['pitchIdx', 'inning', 'frame', 'ab', 'abIdx', 'batter', 'stand',
#        'speed', 'pitchtype', 'px', 'pz', 'szTop', 'szBottom', 'des'],
#       dtype='object')

# %%
lines = pitchDF.plot.line(x='pitchIdx', y='speed', figsize=[12,6])

# %%
color = ['green' if f=='top' else 'yellow' for f in pitchDF['frame'].tolist()]
pitchDF.plot(kind='scatter', x='pitchIdx', y='speed', color=color, figsize=[12,6])

# %% [markdown]
# ## Select operations from the Dataframe

# %%
pitchDF[2:8]
# Out:
#    pitchIdx inning frame ab abIdx           batter stand  speed  pitchtype  \
# 3       3.0      1   top  1     3  Corey Dickerson     L   94.6  4-seam fb
# 4       4.0      1   top  1     4  Corey Dickerson     L   90.5     slider
# 5       5.0      1   top  1     5  Corey Dickerson     L   93.8  4-seam fb
# 6       6.0      1   top  1     6  Corey Dickerson     L   85.0     slider
# 7       7.0      1   top  2     1   Brandon Barnes     R   93.4  4-seam fb
# 8       8.0      1   top  3     1  Troy Tulowitzki     R   94.4  4-seam fb
#
#      px    pz  szTop  szBottom              des
# 3 -1.67  1.33   3.66      1.71             Ball
# 4 -2.00  0.36   3.53      1.58             Ball
# 5 -0.26  3.47   3.40      1.51             Foul
# 6 -0.28  3.33   3.48      1.61    Called Strike
# 7  0.05  2.59   3.53      1.60  In play, out(s)
# 8  0.03  1.09   3.64      1.59             Ball

# %%
pitchDF.loc[pitchDF['ab']=='10']
# Out:
#     pitchIdx inning frame  ab abIdx         batter stand  speed  pitchtype  \
# 41      41.0      2   top  10     1  Wilin Rosario     R   92.0  4-seam fb
# 42      42.0      2   top  10     2  Wilin Rosario     R   92.1  4-seam fb
# 43      43.0      2   top  10     3  Wilin Rosario     R   92.2  4-seam fb
# 44      44.0      2   top  10     4  Wilin Rosario     R   72.6  curveball
#
#       px    pz  szTop  szBottom            des
# 41  0.03  3.89   3.37       1.6           Ball
# 42 -0.34  3.38   3.37       1.6           Foul
# 43 -0.64  2.46   3.37       1.6           Foul
# 44  0.54  2.91   3.37       1.6  Called Strike

# %%
pitchDF.loc[pitchDF['batter']=='Corey Dickerson']
# Out:
#      pitchIdx inning frame  ab abIdx           batter stand  speed  pitchtype  \
# 1         1.0      1   top   1     1  Corey Dickerson     L   93.3  4-seam fb
# 2         2.0      1   top   1     2  Corey Dickerson     L   93.3  4-seam fb
# 3         3.0      1   top   1     3  Corey Dickerson     L   94.6  4-seam fb
# 4         4.0      1   top   1     4  Corey Dickerson     L   90.5     slider
# 5         5.0      1   top   1     5  Corey Dickerson     L   93.8  4-seam fb
# 6         6.0      1   top   1     6  Corey Dickerson     L   85.0     slider
# 123     123.0      4   top  28     1  Corey Dickerson     L   91.7  4-seam fb
# 124     124.0      4   top  28     2  Corey Dickerson     L   72.8  curveball
# 125     125.0      4   top  28     3  Corey Dickerson     L   86.0     slider
# 200     200.0      7   top  49     1  Corey Dickerson     L   92.4  4-seam fb
# 201     201.0      7   top  49     2  Corey Dickerson     L   92.8  4-seam fb
# 202     202.0      7   top  49     3  Corey Dickerson     L   86.0     slider
# 203     203.0      7   top  49     4  Corey Dickerson     L   85.8     slider
# 254     254.0      9   top  65     1  Corey Dickerson     L   94.3  4-seam fb
# 255     255.0      9   top  65     2  Corey Dickerson     L   94.5  4-seam fb
# 256     256.0      9   top  65     3  Corey Dickerson     L   73.6  curveball
# 257     257.0      9   top  65     4  Corey Dickerson     L   86.5     slider
#
#        px    pz  szTop  szBottom              des
# 1   -0.52  1.86   3.40      1.51             Foul
# 2   -0.37  2.75   3.40      1.51  Swinging Strike
# 3   -1.67  1.33   3.66      1.71             Ball
# 4   -2.00  0.36   3.53      1.58             Ball
# 5   -0.26  3.47   3.40      1.51             Foul
# 6   -0.28  3.33   3.48      1.61    Called Strike
# 123  0.26  2.87   3.40      1.51    Called Strike
# 124  0.61  3.39   3.40      1.51    Called Strike
# 125 -0.84  3.36   3.40      1.51  In play, out(s)
# 200  0.08  1.69   3.40      1.51    Called Strike
# 201 -1.89  2.08   3.40      1.51             Ball
# 202 -1.67  2.80   3.40      1.51             Ball
# 203 -0.13  2.19   3.40      1.51  In play, no out
# 254  0.65  3.06   3.40      1.51  Swinging Strike
# 255  0.00  4.02   3.40      1.51             Foul
# 256  0.37  2.89   3.40      1.51             Foul
# 257 -0.66  1.72   3.40      1.51  Swinging Strike

# %% [markdown]
# ## Pitch Plotting (Drawing the Strike Zone)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

"""matplotlib.pyplot is a collection of command shell style functions that make matplotlib 
work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, 
creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
Pyplot maintains state across calls."""

fig1 = plt.figure()
ax1 = fig1.add_subplot(111, aspect='equal')

platewidthInFeet = 17 / 12 # plate is 17 inches wide
expandedPlateInFeet = 20 / 12 # add ball width (half on each side)
szHeightInFeet = 3.5 - 1.5
ballInFeet = 3 / 12
halfBallInFeet = ballInFeet / 2

# draw expanded zone: 3 inch ball (.25 ft) = 1.5 inches all the way around
ax1.add_patch(patches.Rectangle((expandedPlateInFeet/-2, 1.5 - halfBallInFeet), expandedPlateInFeet, szHeightInFeet + ballInFeet, color='lightblue'))

# draw formal zone (plate only)
ax1.add_patch(patches.Rectangle((platewidthInFeet/-2, 1.5), platewidthInFeet, szHeightInFeet))

plt.ylim(0, 5)
plt.xlim(-2, 2)
# Out:
# (-2, 2)

# %% [markdown]
# ## Kershaw Called Balls and Strikes (4 plots)

# %%
pitchCalls = ['Called Strike', 'Ball']
sides = ['R', 'L']
colors = {'R':'red', 'L':'black'} 
markers = {'R':'x', 'L':'o'}

for pitchCall in pitchCalls:
    for sidename in sides: 
        df = pitchDF.loc[pitchDF['des']==pitchCall].loc[pitchDF['frame']=='top']
        mark = markers[sidename]
        colr = colors[sidename]
        #print("Group:" + sidename )
        df_side = df.loc[pitchDF['stand']==sidename] 
        ax1 = df_side.plot(kind='scatter', x='px', y='pz', marker=mark, color=colr, figsize=[8,8], ylim=[0,4], xlim=[-2,2])

        if sidename == 'R':
            xcoord = -1.6
            handers = "right handers"
        else: 
            xcoord = 1.4
            handers = "left handers"
        txtbatter = ax1.text(xcoord, 2.5, sidename, style='italic', fontsize=24, color=colr,
                bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10})

        ax1.set_xlabel(pitchCall + "s to " + handers + " (catcher's view).")
        ax1.set_ylabel('vertical location')
        ax1.set_aspect(aspect=1)

        platewidthInFeet = 17 / 12 # plate is 17 inches wide
        expandedPlateInFeet = 20 / 12 # add ball width (half on each side)
        szTop = df["szTop"].iloc[0]
        szBottom = df["szBottom"].iloc[0]
        szHeightInFeet = szTop - szBottom
        ballInFeet = 3 / 12
        halfBallInFeet = ballInFeet / 2
        # draw expanded zone
        outrect = ax1.add_patch(patches.Rectangle((expandedPlateInFeet/-2, szBottom - halfBallInFeet), 
                                                  expandedPlateInFeet, szHeightInFeet + ballInFeet, color='lightblue'))
        # draw formal zone
        rect = ax1.add_patch(patches.Rectangle((platewidthInFeet/-2, szBottom), platewidthInFeet, szHeightInFeet))
        outrect.zorder=-2 
        rect.zorder=-1 
        
        plt.ylim(0, 5)
        plt.xlim(-2.5, 2.5)

# %% [markdown]
# ### Dickerson AtBat #1

# %%
df = pitchDF.loc[pitchDF['ab']=='1'] # first atbat of the game

ax1 = df.plot(kind='scatter', x='px', y='pz', color='red', figsize=[7,7], ylim=[0,4], xlim=[-2,2])
ax1.set_xlabel("Catcher's View - horizontal location")
ax1.set_ylabel('vertical location')
ax1.set_aspect(aspect=1)

platewidthInFeet = 17 / 12 # plate is 17 inches wide
expandedPlateInFeet = 20 / 12 # add ball width (half on each side)
szTop = df["szTop"].iloc[0]
szBottom = df["szBottom"].iloc[0]
szHeightInFeet = szTop - szBottom
ballInFeet = 3 / 12
halfBallInFeet = ballInFeet / 2
# draw expanded zone
outrect = ax1.add_patch(patches.Rectangle((expandedPlateInFeet/-2, szBottom - halfBallInFeet), 
                                          expandedPlateInFeet, szHeightInFeet + ballInFeet, color='lightblue'))
# draw formal zone
rect = ax1.add_patch(patches.Rectangle((platewidthInFeet/-2, szBottom), platewidthInFeet, szHeightInFeet))

outrect.zorder=-2 
rect.zorder=-1 
plt.ylim(0, 5)
plt.xlim(-2.5, 2.5)

stand = df['stand'].iloc[0]
if  stand == 'R':
    standTextX = -1.5
else:
    standTextX = 1.4
tbatter = ax1.text(standTextX, 2.5, stand, style='italic', fontsize=24,
        bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10})

# %% [markdown]
# ### Label Pitches

# %%
df = pitchDF.loc[pitchDF['ab']=='1']
#print(df)
stand = df['stand'].iloc[0]
batter = df['batter'].iloc[0]
inning = df['inning'].iloc[0]
frame = df["frame"].iloc[0]
suffix = "th"
suffix = "st" if inning == '1' else suffix
suffix = "nd" if inning == '2' else suffix
suffix = "rd" if inning == '3' else suffix

#print("Batter:" + batter)
ax1 = df.plot(kind='scatter', x='px', y='pz', color='red', figsize=[7,7], ylim=[0,4], xlim=[-2,2])
ax1.set_xlabel("Catcher's View - " + batter + " (" + frame + " of the " + inning + suffix + ")")
ax1.set_ylabel('vertical location')
ax1.set_aspect(aspect=1)
plt.ylim(0, 5)
plt.xlim(-2.5, 2.5)

platewidthInFeet = 17 / 12 # plate is 17 inches wide
expandedPlateInFeet = 20 / 12 # add ball width (half on each side)
szTop = df["szTop"].iloc[0]
szBottom = df["szBottom"].iloc[0]
szHeightInFeet = szTop - szBottom
# draw expanded zone: 3 inch ball (.25 ft) = 1.5 inches all the way around
outrect = ax1.add_patch(patches.Rectangle((expandedPlateInFeet/-2, szBottom - 0.125), expandedPlateInFeet, szHeightInFeet + 0.25, color='lightblue'))
rect = ax1.add_patch(patches.Rectangle((platewidthInFeet/-2, szBottom), platewidthInFeet, szHeightInFeet))
outrect.zorder=-2 
rect.zorder=-1 

if stand == 'R':
    standTextX = -1.5
else:
    standTextX = 1.4
tbatter = ax1.text(standTextX, 2.5, stand, style='italic', fontsize=24,
        bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10})

#label pitch points
ptypes = df["pitchtype"]
xcoords = df["px"]
ycoords = df["pz"]
speed = df["speed"]
abIdx = df["abIdx"]

for i, txt in enumerate(ptypes):
    print(abIdx.iloc[i], txt, xcoords.iloc[i], ycoords.iloc[i])
    txtDetail = str(abIdx.iloc[i]) + ") " + txt +  " (" + str(int(speed.iloc[i])) + "mph)"
    txt = ax1.text(xcoords.iloc[i]+.1, ycoords.iloc[i]-.05, txtDetail, style='italic', fontsize=12)
# Out:
# 1 4-seam fb -0.52 1.86
# 2 4-seam fb -0.37 2.75
# 3 4-seam fb -1.67 1.33
# 4 slider -2.0 0.36
# 5 4-seam fb -0.26 3.47
# 6 slider -0.28 3.33

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from numpy.random import random

df = pitchDF.loc[pitchDF['ab']=='1']

pitchColors = { "FA":"b", "FF":"b", "FT": "y", "FC": "k", "":"w", None: "violet",
                    "FS":"aqua", "SL":"red", "CH":"h","CU":"gold","KC":"tan",
                    "KN":"^","EP":"*", "UN":"X", "PO":"s", "SI":"_", "SF":"seagreen"
                    }
pitchMarkers = { "FA":"x", "FF":"o", "FT": "1", "FC": "2", "":"2", None: "4",
                    "FS":"aqua", "SL":"^", "CH":"h","CU":"gold","KC":"tan",
                    "KN":"^","EP":"*", "UN":"X", "PO":"s", "SI":"_", "SF":"seagreen"
                    }

# define the dataframe slice (one at bat)

stand = df['stand'].iloc[0]
batter = df['batter'].iloc[0]
inning = df['inning'].iloc[0]
frame = df["frame"].iloc[0]
suffix = "th"
suffix = "st" if inning == '1' else suffix
suffix = "nd" if inning == '2' else suffix
suffix = "rd" if inning == '3' else suffix

plt.figure(figsize=(7,7)) 

platewidthInFeet = 17 / 12 # plate is 17 inches wide
expandedPlateInFeet = 20 / 12 # add ball width (half on each side)
szTop = df["szTop"].iloc[0]
szBottom = df["szBottom"].iloc[0]
szHeightInFeet = szTop - szBottom
# draw expanded zone: 3 inch ball (.25 ft) = 1.5 inches all the way around

currentAxis = plt.gca()
currentAxis.add_patch(Rectangle((expandedPlateInFeet/-2, szBottom - 0.125), expandedPlateInFeet, szHeightInFeet + 0.25, color='lightblue'))
currentAxis.add_patch(Rectangle((platewidthInFeet/-2, szBottom), platewidthInFeet, szHeightInFeet, facecolor="lightgrey"))
if stand == 'R':
    standTextX = -1.5
else:
    standTextX = 1.4
tbatter = currentAxis.text(standTextX, 2.5, stand, style='italic', fontsize=24,
        bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10})

pitchList = []
availColors = ['b','r','y','k','w']
pitchesUsed = df['pitchtype'].unique()
abCount = len(df['speed'])
markerSize = [0] * abCount
for i, sx in enumerate(df['speed'].tolist()):
    markerSize[i] = int(sx -  70)*3
    thrownPitch = df['pitchtype'].tolist()[i]
    for j, (k, v) in enumerate(pitchDictionary.items()):
        if thrownPitch == v:
            pitchList.append(plt.scatter(df['px'].iloc[i], df['pz'].iloc[i], marker=pitchMarkers[k], 
                                         color=pitchColors[k], label=v, zorder=2))
            #print("i: {} j: {} pitch: {}, key: {}, value: {} marker: {} color:{}".format(i, j, thrownPitch, k, v, pitchMarkers[k], pitchColors[k]))
            
print(markerSize, colors, pitchesUsed)

# graph limits
plt.ylim(0, 5)
plt.xlim(-2.5, 2.5)
plt.gca().set_aspect('equal', 'box')

# draw legend by consolidating like pitch types
handles, labels = plt.gca().get_legend_handles_labels()
newLabels, newHandles = [], []
for handle, label in zip(handles, labels):
    if label not in newLabels:
        newLabels.append(label)
        newHandles.append(handle)
plt.legend(newHandles, newLabels)

# axis labels
plt.xlabel("Catcher's View - " + batter + " (" + frame + " of the " + inning + suffix + ")")
plt.ylabel('vertical location')

plt.show()
# Out:
# [69, 69, 72, 60, 69, 45] ['b', 'b', 'b', 'b', 'b', 'b'] ['4-seam fb' 'slider']

# %% [markdown]
# ### Add Ball-Strike Count to Dataframne

# %%
uniqDesList = pitchDF.des.unique()
print(uniqDesList)
# Declare a list that is to be converted into a column 
ballColList = [] 
strikeColList = []
ballCount = 0
strikeCount = 0

for index, row in pitchDF.iterrows():
    des = row['des']
    if row['abIdx'] == 1: # first pitch in ab
        ballCount = 0
        strikeCount = 0
        
    # save count before this pitch was thrown, then update count
    ballColList.append(ballCount)
    strikeColList.append(strikeCount)
    #print(index, row['ab'], row['abIdx'], row['des'], ballCount, strikeCount)
    
    if 'Ball' in des:
        ballCount = ballCount + 1
    elif 'Foul' in des:
        if strikeCount is not 2:
            strikeCount = strikeCount + 1
    elif 'Strike' in des:
        strikeCount = strikeCount + 1
    
# print(ballColList, strikeColList)
pitchDF['ballCount'] = ballColList # equate column to list
pitchDF['strikeCount'] = strikeColList # equate column to list
# Out:
# ['Foul' 'Swinging Strike' 'Ball' 'Called Strike' 'In play, out(s)'
#  'Ball In Dirt' 'In play, run(s)' 'Swinging Strike (Blocked)' 'Foul Tip'
#  'In play, no out']

# %%
pitchDF.head(25)
# Out:
#     pitchIdx inning   frame ab abIdx              batter stand  speed  \
# 1        1.0      1     top  1     1     Corey Dickerson     L   93.3
# 2        2.0      1     top  1     2     Corey Dickerson     L   93.3
# 3        3.0      1     top  1     3     Corey Dickerson     L   94.6
# 4        4.0      1     top  1     4     Corey Dickerson     L   90.5
# 5        5.0      1     top  1     5     Corey Dickerson     L   93.8
# 6        6.0      1     top  1     6     Corey Dickerson     L   85.0
# 7        7.0      1     top  2     1      Brandon Barnes     R   93.4
# 8        8.0      1     top  3     1     Troy Tulowitzki     R   94.4
# 9        9.0      1     top  3     2     Troy Tulowitzki     R   88.0
# 10      10.0      1     top  3     3     Troy Tulowitzki     R   72.4
# 11      11.0      1     top  3     4     Troy Tulowitzki     R   87.2
# 12      12.0      1     top  3     5     Troy Tulowitzki     R   93.8
# 13      13.0      1  bottom  4     1  Dee Strange-Gordon     L   90.1
# 14      14.0      1  bottom  4     2  Dee Strange-Gordon     L   90.8
# 15      15.0      1  bottom  4     3  Dee Strange-Gordon     L   90.5
# 16      16.0      1  bottom  4     4  Dee Strange-Gordon     L   91.8
# 17      17.0      1  bottom  4     5  Dee Strange-Gordon     L   91.2
# 18      18.0      1  bottom  4     6  Dee Strange-Gordon     L   92.4
# 19      19.0      1  bottom  4     7  Dee Strange-Gordon     L   92.6
# 20      20.0      1  bottom  4     8  Dee Strange-Gordon     L   92.9
# 21      21.0      1  bottom  5     1      Hanley Ramirez     R   91.7
# 22      22.0      1  bottom  5     2      Hanley Ramirez     R   87.4
# 23      23.0      1  bottom  5     3      Hanley Ramirez     R   92.3
# 24      24.0      1  bottom  5     4      Hanley Ramirez     R   92.4
# 25      25.0      1  bottom  5     5      Hanley Ramirez     R   92.5
#
#     pitchtype    px    pz  szTop  szBottom              des  ballCount  \
# 1   4-seam fb -0.52  1.86   3.40      1.51             Foul          0
# 2   4-seam fb -0.37  2.75   3.40      1.51  Swinging Strike          0
# 3   4-seam fb -1.67  1.33   3.66      1.71             Ball          0
# 4      slider -2.00  0.36   3.53      1.58             Ball          1
# 5   4-seam fb -0.26  3.47   3.40      1.51             Foul          2
# 6      slider -0.28  3.33   3.48      1.61    Called Strike          2
# 7   4-seam fb  0.05  2.59   3.53      1.60  In play, out(s)          0
# 8   4-seam fb  0.03  1.09   3.64      1.59             Ball          0
# 9      slider -1.39  0.61   3.58      1.71  Swinging Strike          1
# 10  curveball  0.59  4.08   3.38      1.75             Ball          1
# 11     slider -0.60  1.75   3.58      1.71             Foul          2
# 12  4-seam fb  0.96  3.39   3.58      1.71  In play, out(s)          2
# 13  4-seam fb -0.75  0.71   3.29      1.48             Ball          0
# 14  4-seam fb -0.77  1.23   3.28      1.48             Ball          1
# 15  4-seam fb  0.66  2.45   3.28      1.51    Called Strike          2
# 16  4-seam fb -2.36  1.59   3.35      1.41             Ball          2
# 17  4-seam fb  0.51  2.84   3.22      1.41    Called Strike          3
# 18  4-seam fb -0.27  2.61   3.36      1.48             Foul          3
# 19  4-seam fb  0.20  2.81   3.36      1.48             Foul          3
# 20  4-seam fb -0.98  0.36   3.39      1.52     Ball In Dirt          3
# 21  4-seam fb  0.09  2.07   3.51      1.63             Foul          0
# 22  fb-cutter -0.83  2.02   3.51      1.63             Foul          0
# 23  4-seam fb -1.65  1.03   3.55      1.65             Ball          0
# 24  4-seam fb -0.26  0.87   3.61      1.84             Ball          1
# 25  4-seam fb  1.09  1.23   3.48      1.74             Ball          2
#
#     strikeCount
# 1             0
# 2             1
# 3             2
# 4             2
# 5             2
# 6             2
# 7             0
# 8             0
# 9             0
# 10            1
# 11            1
# 12            2
# 13            0
# 14            0
# 15            0
# 16            1
# 17            1
# 18            2
# 19            2
# 20            2
# 21            0
# 22            1
# 23            2
# 24            2
# 25            2

# %% [markdown]
# ## Show Kershaw pitch tendency by count

# %%
titleList = []
dataList = []
fig, axes = plt.subplots(4, 3, figsize=(12,16))

for b in range(4):
    for s in range(3):
        #print("Count:",str(b),str(s))
        df = pitchDF.loc[(pitchDF['ballCount']==b) & (pitchDF['strikeCount']==s) & (pitchDF['frame']=='top')]
        title = "Count:" + str(b) + "-" + str(s) + " (" + str(len(df)) + ")"
        titleList.append(title)
        dataList.append(df)
        #if df.size > 0:  #empty - no count encountered
       
for i, ax in enumerate(axes.flatten()):
    x = dataList[i].pitchtype.value_counts() 
    l = dataList[i].pitchtype.unique()
    #print(x)
    ax.pie(x, radius = 1, autopct="%.1f%%", pctdistance=0.9, labels=l)
    ax.set_title(titleList[i])

plt.show()

# %%
df.head()
# Out:
#     pitchIdx inning frame  ab abIdx         batter stand  speed  pitchtype  \
# 56      56.0      2   top  12     7  Josh Rutledge     R   93.1  4-seam fb
# 57      57.0      2   top  12     8  Josh Rutledge     R   88.2     slider
#
#       px    pz  szTop  szBottom              des  ballCount  strikeCount
# 56 -0.84  3.12   3.46      1.57             Foul          3            2
# 57  0.46  2.18   3.46      1.57  In play, out(s)          3            2

# %%
import matplotlib.pyplot as plt

title = "PitchCount:" + str(df['ballCount'].iloc[0]) + "-" + str(df['strikeCount'].iloc[0])
print(title)
 
df.pitchtype.value_counts().plot(kind='pie')
plt.axis('equal')
plt.title(title)
# Out:
# PitchCount:3-2
# Text(0.5, 1.0, 'PitchCount:3-2')
